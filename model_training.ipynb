# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11m.yaml")

results = model.train(data="hackaton_dataset/data.yaml", epochs=60, imgsz=640, model="yolo11m.yaml", batch=8)
# Out:
# New https://pypi.org/project/ultralytics/8.3.204 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.203  Python-3.13.7 torch-2.8.0+cu129 CUDA:0 (NVIDIA GeForce RTX 5060, 8151MiB)
# ...

# %%
import torch
print(torch.cuda.is_available())
